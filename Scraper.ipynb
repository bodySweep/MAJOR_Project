# %%
import requests
import urllib.request
from bs4 import BeautifulSoup
from urllib.request import urlopen

url = 'https://en.wikipedia.org/wiki/Cricket'
html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')
link_list = []
final_list = set()
for link in soup.find_all('a'):
    if(link.get('href') is not None):
        if((link.get('href').find('#')==-1) and (link.get('href').find(':')==-1) and (link.get('href').find('/w/')==-1)):
            link_list.append(link.get('href'))
            final_list.add(link.get('href'))
print(len(link_list))
print(len(final_list))
definitions = []
link_list
#print(type(link_list[6]))
# res1 = '#'
# res2 = 'None'
# if(link.find(res1)!=1 and link.find(res2)!=1):
#     link_list.append(link.get('href'))
# Out:
# 1347
# 932
# ['/wiki/Cricket_(insect)',
#  '/wiki/Cricket_(disambiguation)',
#  '/wiki/Cricketer_(disambiguation)',
#  '/wiki/Eden_Gardens',
#  '/wiki/2016_ICC_World_Twenty20_Final',
#  '/wiki/Sports_governing_body',
#  '/wiki/International_Cricket_Council',
#  '/wiki/Substitute_(cricket)',
#  '/wiki/Mixed-sex_sports',
#  '/wiki/Team_sport',
#  '/wiki/Bat-and-ball_games',
#  '/wiki/Cricket_ball',
#  '/wiki/Cricket_bat',
#  '/wiki/Wicket',
#  '/wiki/Stump_(cricket)',
#  '/wiki/Bail_(cricket)',
#  '/wiki/Cricket_clothing_and_equipment',
#  '/wiki/Cricket_field',
#  '/wiki/Glossary_of_cricket_terms',
#  '/wiki/Commonwealth_of_Nations',
#  '/wiki/British_Overseas_Territories',
#  '/wiki/South_Asia',
#  '/wiki/Olympic_Games',
#  '/wiki/1900_Summer_Olympics',
#  '/wiki/Forms_of_cricket',
#  '/wiki/Test_cricket',
#  '/wiki/Women%27s_Test_cricket',
#  '/wiki/First-class_cricket',
#  '/wiki/Women%27s_cricket',
#  '/wiki/One_Day_International',
#  '/wiki/Women%27s_One_Day_International',
# ...

# %%
import wikipedia
print(wikipedia.summary("Cricket", sentences = 2))
# Out:
# Cricket is a bat-and-ball game played between two teams of eleven players each on a field at the centre of which is a 22-yard (20-metre) pitch with a wicket at each end, each comprising two bails balanced on three stumps. The game proceeds when a player on the fielding team, called the bowler, "bowls" (propels) the ball from one end of the pitch towards the wicket at the other end, with an "over" being completed once they have legally done so six times.

# %%
print wikipedia.summary("Wikipedia")
# Out:
#   File "C:\Users\LENOVO\AppData\Local\Temp/ipykernel_17040/1752575765.py", line 1
#     print wikipedia.summary("Wikipedia")
#           ^
# SyntaxError: invalid syntax
